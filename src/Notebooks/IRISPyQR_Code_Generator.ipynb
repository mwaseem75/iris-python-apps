# %% [markdown]
# # QR Code generation by using Python qrcode liabrary

# %%
import qrcode
import matplotlib.pyplot as plt

# %%
data = "Intersystems Python QR CODE generator"
filename = "IRISQRCode.png"

image = qrcode.make(data)

image.save(filename)
plt.imshow(image,cmap='gray')

# %%
from PIL import Image
import pytesseract
import os

def ocr_core(filename):
    """
    This function will handle the core OCR processing of images.
    """
    pytesseract.pytesseract.tesseract_cmd = "\opt\irisapp\misc\tesseract.exe"
    text = pytesseract.image_to_string(Image.open(os.path.join(filename)))
    return text
print(ocr_core('/opt/irisapp/misc/EmbeddedPython.png'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/pytesseract/pytesseract.py:252, in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     251 try:
# --> 252     proc = subprocess.Popen(cmd_args, **subprocess_args())
#     253 except OSError as e:
#
# File /usr/lib/python3.8/subprocess.py:858, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     855             self.stderr = io.TextIOWrapper(self.stderr,
#     856                     encoding=encoding, errors=errors)
# --> 858     self._execute_child(args, executable, preexec_fn, close_fds,
#     859                         pass_fds, cwd, env,
# ...

# %%
# !pip3 install pytesseract
# Out:
# ...
#   Created wheel for pytesseract: filename=pytesseract-0.3.8-py2.py3-none-any.whl size=14063 sha256=10556aea278997c1623db0c379fa686ebc6627f0391a0e4115d8763865314e29
#   Stored in directory: /home/irisowner/.cache/pip/wheels/ed/8a/c6/40c7ec06c2dd3df636832537238128a1471bf9c1b6a3a9bf40
# Successfully built pytesseract
# ...
#   WARNING: The script pytesseract is installed in '/home/irisowner/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
