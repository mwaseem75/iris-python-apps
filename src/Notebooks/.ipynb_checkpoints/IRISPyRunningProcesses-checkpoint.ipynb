# %%
import pandas as pd
pd.options.display.max_rows = 9

import iris
statement = iris.sql.exec('SELECT * FROM %SYS.ProcessQuery')
df = statement.dataframe()
df
#df = pd.read_csv('/opt/irisapp/misc/titanic.csv')

#print(df.to_string()) 
#df
#print(df.head(10))
#print(df.info()) 
#df
#df.duplicated()
#df.corr()
# Out:
#       id namespace                     routine  linesexecuted  \
# 0    394                               CONTROL              0
# 1    435                                WRTDMN            651
# 2    436                                GARCOL              0
# 3    437                                JRNDMN           3387
# ..   ...       ...                         ...            ...
# 28  2029      USER  %SYS.Python.SQLResultSet.1         775617
# 29  1887      %SYS           %SYS.WorkQueueMgr         162795
# 30  1888      %SYS           %SYS.WorkQueueMgr         169708
# 31  3288      USER                   Unknown47         139922
#
#     globalreferences state pidexternal   username clientipaddress  \
# 0                  0   RUN         394
# 1               1839  RUNW         435
# 2                  0  RUNW         436
# 3                326  RUNW         437
# ..               ...   ...         ...        ...             ...
# 28             31004   RUN        2029  irisowner
# 29             16393  EVTW        1887
# 30             17675  EVTW        1888
# 31              9958   RUN        3288  irisowner
#
#    clientnodename  ... globalblocks journalentries memorypeak roles  \
# 0                  ...            0              0         58  %All
# 1                  ...            0              0         58  %All
# 2                  ...            0              0         58  %All
# 3                  ...            0              0         58  %All
# ..            ...  ...          ...            ...        ...   ...
# 28                 ...           10              1       1146  %All
# 29             -2  ...           11              0        256  %All
# 30             -2  ...            7            213        256  %All
# 31                 ...            0              1        860  %All
#
#    loginroles datablockwrites  privateglobalreferences  privateglobalupdates  \
# 0        %All               0                        0                     0
# 1        %All               0                        0                     0
# 2        %All               0                        0                     0
# 3        %All               0                        0                     0
# ..        ...             ...                      ...                   ...
# 28       %All              37                      322                   204
# 29       %All               8                      379                   181
# 30       %All              14                      186                    89
# 31       %All               3                        0                     0
#
#    cputime  appframeinfo
# 0     1660
# 1     2780
# 2        0
# 3      240
# ..     ...           ...
# 28    4500
# 29    1550
# 30    4960
# 31    3130
#
# [32 rows x 51 columns]
